# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/2010-19.csv')
data.head(10)
# Out:
#    Unnamed: 0 Div      Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0           0  E0  14/08/10  Aston Villa    West Ham   3.0   0.0   H   2.0
# 1           1  E0  14/08/10    Blackburn     Everton   1.0   0.0   H   1.0
# 2           2  E0  14/08/10       Bolton      Fulham   0.0   0.0   D   0.0
# 3           3  E0  14/08/10      Chelsea   West Brom   6.0   0.0   H   2.0
# 4           4  E0  14/08/10   Sunderland  Birmingham   2.0   2.0   D   1.0
# 5           5  E0  14/08/10    Tottenham    Man City   0.0   0.0   D   0.0
# 6           6  E0  14/08/10        Wigan   Blackpool   0.0   4.0   A   0.0
# 7           7  E0  14/08/10       Wolves       Stoke   2.0   1.0   H   2.0
# 8           8  E0  15/08/10    Liverpool     Arsenal   1.0   1.0   D   0.0
# 9           9  E0  16/08/10   Man United   Newcastle   3.0   0.0   H   2.0
#
#    HTAG  ... BbAvAHH BbMxAHA  BbAvAHA   Season  PSH  PSD  PSA  PSCH  PSCD  \
# ...

# %%
class Team():
    def __init__(self, team):
        self.team = team
        self.standings = self._standings()
        
    def _standings(self):
